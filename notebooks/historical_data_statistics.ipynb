# %% [markdown]
# # Historical Data Statistics
#
# Notebook dedicado aos testes estat?sticos sobre `classification_metrics.csv`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import matplotlib.pyplot as plt
import pandas as pd

from src.analysis.historical_statistics import average_model_ranks, run_friedman_test, run_nemenyi_test

# %%
results_df = pd.read_csv(PROJECT_ROOT / 'classification_metrics.csv')
results_df

# %%
friedman_result = run_friedman_test(results_df, metric='f1_score')
friedman_result['statistic'], friedman_result['p_value']

# %%
friedman_result['pivoted']

# %%
average_model_ranks(results_df, metric='f1_score')

# %%
nemenyi = run_nemenyi_test(results_df, metric='f1_score')
nemenyi
